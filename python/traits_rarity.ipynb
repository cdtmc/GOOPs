# %%
import csv
import pandas
import numpy

# %%
goop_df = pandas.read_csv('goops_with_traits.csv')
goop_df = goop_df.drop('id', 1)
print(goop_df.head(5))
# Out:
#   bgcolor               body                       accessory          head  \
# 0  d5d7e1      body-peachy-a    accessory-checkers-big-green   head-flower
# 1  e1d7d5  body-computerblue      accessory-glasses-logo-sun  head-porkbao
# 2  e1d7d5      body-hotbrown          accessory-matrix-white    head-moose
# 3  d5d7e1           body-red  accessory-hoodiestrings-uneven     head-weed
# 4  d5d7e1          body-rust    accessory-tie-black-on-white   head-flower
#
#                               glasses
# 0           glasses-square-frog-green
# 1  glasses-square-yellow-orange-multi
# 2                glasses-square-honey
# 3  glasses-square-yellow-orange-multi
# 4     glasses-square-green-blue-multi

# %%
goop_df['body'].value_counts()
# Out:
# body-hotbrown         365
# body-blue-sky         365
# body-slimegreen       364
# body-grayscale-1      364
# body-peachy-B         352
# body-computerblue     352
# body-yellow           352
# body-grayscale-9      352
# body-gunk             350
# body-rust             350
# body-green            346
# body-redpinkish       345
# body-darkpink         342
# body-purple           340
# body-cold             338
# body-grayscale-7      336
# body-bege-crt         333
# body-orange           327
# body-orange-yellow    325
# body-red              323
# body-foggrey          323
# body-bluegrey         318
# body-bege-bsod        316
# body-peachy-a         315
# body-teal             311
# body-teal-light       305
# body-gold             302
# body-darkbrown        299
# body-grayscale-8      296
# body-magenta          294
# Name: body, dtype: int64

# %%
goop_df['accessory'].value_counts()
# Out:
# accessory-wave                  97
# accessory-bling-arrow           94
# accessory-glasses               91
# accessory-checkers-big-green    89
# accessory-tie-black-on-white    88
#                                 ..
# accessory-dollar-bling          62
# accessory-pizza-bling           59
# accessory-bling-sparkles        58
# accessory-txt-mint              54
# accessory-leaf                  49
# Name: accessory, Length: 137, dtype: int64

# %%
goop_df['head'].value_counts()
# Out:
# head-nigiri              61
# head-goldfish            60
# head-cookie              60
# head-chipboard           57
# head-pumpkin             57
#                          ..
# head-toiletpaper-full    30
# head-mustard             29
# head-hardhat             28
# head-sandwich            27
# head-coffeebean          24
# Name: head, Length: 234, dtype: int64

# %%
goop_df['glasses'].value_counts()
# Out:
# glasses-square-blue                   529
# glasses-square-yellow-saturated       506
# glasses-square-guava                  500
# glasses-square-orange                 500
# glasses-square-blue-med-saturated     489
# glasses-square-black-rgb              489
# glasses-square-black-eyes-red         484
# glasses-square-green-blue-multi       482
# glasses-square-smoke                  479
# glasses-square-watermelon             478
# glasses-square-fullblack              476
# glasses-square-magenta                471
# glasses-square-yellow-orange-multi    470
# glasses-square-frog-green             468
# glasses-square-red                    467
# glasses-square-honey                  460
# glasses-square-pink-purple-multi      456
# glasses-square-black                  455
# glasses-square-teal                   454
# glasses-square-grey-light             451
# glasses-hip-rose                      436
# Name: glasses, dtype: int64

# %%
goop_df.iloc[2443]
# Out:
# bgcolor                           d5d7e1
# body                       body-darkpink
# accessory    accessory-body-gradient-ice
# head                        head-stapler
# glasses           glasses-square-magenta
# Name: 2443, dtype: object

# %%
goop_df.loc[(goop_df['head']=='head-cheese')]
# Out:
#      bgcolor               body                             accessory  \
# 345   e1d7d5        body-purple              accessory-woolweave-dirt
# 430   e1d7d5          body-gold     accessory-checker-bigwalk-rainbow
# 434   e1d7d5       body-magenta                          accessory-id
# 652   d5d7e1   body-grayscale-7              accessory-woolweave-dirt
# 1058  e1d7d5      body-peachy-B                    accessory-txt-lmao
# 1080  e1d7d5     body-darkbrown           accessory-body-gradient-ice
# 1121  e1d7d5    body-redpinkish               accessory-taxi-checkers
# 1218  e1d7d5  body-computerblue         accessory-txt-noun-multicolor
# 1605  e1d7d5      body-darkpink  accessory-body-gradient-checkerdisco
# 1707  d5d7e1      body-blue-sky                    accessory-txt-noun
# 1748  e1d7d5    body-slimegreen                        accessory-wall
# 1857  e1d7d5    body-teal-light        accessory-checker-spaced-white
# ...

# %%
sea_animal_heads = ['head-crab','head-croc-hat','head-goldfish','head-grouper',
                    'head-jellyfish', 
                'head-orca', 'head-otter', 'head-owl','head-pufferfish','head-shark',
                    'head-squid',
                'head-whale-alive','head-whale',]

land_animal_heads = ['head-aardvark','head-ape','head-bat','head-bear', 'head-cat',
                     'head-chameleon', 'head-chicken','head-cow','head-dog', 'head-fox',
                     'head-frog',
                     'head-goat', 'head-horse-deepfried','head-kangaroo','head-moose',
                     'head-mosquito',
                     'head-mouse','head-orangutan','head-panda','head-rabbit',
                     'head-scorpion','head-zebra']

bird_heads = ['head-crane','head-duck','head-flamingo','head-raven']

mythical_heads = ['head-bigfoot-yeti','head-bigfoot','head-dino','head-unicorn', 
                  'head-werewolf','head-ghost-B','head-gnome','head-robot',
                  'head-undead','head-skeleton-hat']

food_heads = ['head-banana','head-beet','head-blueberry','head-bubblegum',
              'head-burger-dollarmenu', 'head-cake', 'head-cannedham','head-cheese',
              'head-cherry', 'head-chilli', 'head-chips', 'head-chocolate', 
              'head-coffeebean',
              'head-cookie', 'head-doughnut','head-egg','head-hotdog', 'head-icepop-b',
              'head-ketchup', 'head-macaroni','head-mushroom','head-mustard',
              'head-nigiri','head-noodles','head-onion','head-oyster', 'head-peanut',
              'head-pickle','head-pie','head-pineapple','head-pizza','head-pop', 
              'head-porkbao', 'head-potato','head-pumpkin','head-sandwich','head-spaghetti',
              'head-steak','head-taco-classic','head-watermelon']

drink_heads = ['head-beer','head-milk','head-wine']

human_part_heads = ['head-brain', 'head-dna','head-hair','head-heart','head-lips',
                    'head-smile','head-thumbsup','head-tooth']

object_heads = ['head-bagpipe','head-bell', 'head-bomb',
                 'head-box','head-calendar',
                'head-cash-register',
                'head-chainsaw','head-chart-bars',
                'head-cottonball', 
                'head-crystalball', 'head-dictionary','head-drill','head-ducky',
                'head-fan','head-firehydrant',
                'head-gavel','head-goldcoin',
                'head-lipstick2', 'head-lock',
                'head-mailbox','head-microwave','head-mirror','head-mixer','head-mug',
                'head-paperclip','head-pencil-tip',
                'head-piano', 'head-piggybank', 'head-pill', 'head-pillow','head-pipe',
                'head-retainer','head-ruler-triangular',
                'head-saw','head-shower',
                'head-snowglobe','head-snowmobile', 'head-sponge','head-stapler',
                'head-toaster', 'head-toiletpaper-full', 'head-toothbrush-fresh',
                'head-trashcan','head-vent','head-wallsafe',
                'head-washingmachine','head-weight']

clothing_heads = ['head-bag','head-boot','head-chain','head-chefhat','head-clutch',
                  'head-crown', 'head-glasses-big', 'head-hardhat', 'head-higheel',
                  'head-lint', 'head-queencrown', 'head-ring','head-wallet', 
                  'head-wizardhat']

art_heads = ['head-abstract', 'head-rgb', 'head-bubble-speech', 'head-paintbrush', 
             'head-faberge']

transport_heads = ['head-car','head-cone','head-helicopter','head-plane','head-pirateship',
                   'head-road','head-sailboat','head-skateboard','head-skilift','head-taxi']

technology_heads = ['head-boombox','head-calculator','head-camcorder','head-cassettetape',
                    'head-cd','head-chipboard','head-cordlessphone','head-crt-bsod',
                    'head-film-35mm','head-film-strip','head-laptop','head-outlet',
                    'head-rangefinder','head-turing','head-watch','head-console-handheld']

building_heads = ['head-bank','head-factory-dark','head-fence','head-house','head-igloo',
                  'head-pyramid','head-wall']

sports_heads = ['head-baseball-gameball', 'head-basketball','head-boxingglove',
                'head-hockeypuck','head-volleyball']

space_heads = ['head-blackhole','head-earth','head-jupiter','head-moon','head-saturn',
               'head-star-sparkles','head-ufo','head-void']

nature_heads = ['head-bonsai', 'head-cloud', 'head-clover', 'head-diamond-red', 
                'head-diamond-blue','head-fir','head-flower','head-garlic', 'head-island',
                'head-lightning-bolt','head-maze','head-mountain-snowcap', 'head-peyote',
                'head-rainbow','head-rock','head-rosebud','head-saguaro','head-sunset',
                'head-tornado','head-volcano','head-wave','head-weed']

# %%
for head in sea_animal_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'sea_animal'
    
for head in land_animal_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'land_animal'
    
for head in bird_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'bird'
    
for head in mythical_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'mythical'
    
for head in food_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'food'
    
for head in human_part_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'human_part'
    
for head in object_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'object'
    
for head in art_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'art'
    
for head in transport_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'transport'
    
for head in technology_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'technology'
    
for head in building_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'building'
    
for head in sports_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'sports'
    
for head in space_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'space'
        
for head in nature_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'nature'
    
for head in clothing_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'clothing'
    
for head in drink_heads:
    goop_df.loc[goop_df['head'].str.contains(head),'catergory'] = 'drink'
    
    
goop_df.head()
# Out:
#   bgcolor               body                       accessory          head  \
# 0  d5d7e1      body-peachy-a    accessory-checkers-big-green   head-flower
# 1  e1d7d5  body-computerblue      accessory-glasses-logo-sun  head-porkbao
# 2  e1d7d5      body-hotbrown          accessory-matrix-white    head-moose
# 3  d5d7e1           body-red  accessory-hoodiestrings-uneven     head-weed
# 4  d5d7e1          body-rust    accessory-tie-black-on-white   head-flower
#
#                               glasses    catergory
# 0           glasses-square-frog-green       nature
# 1  glasses-square-yellow-orange-multi         food
# 2                glasses-square-honey  land_animal
# 3  glasses-square-yellow-orange-multi       nature
# 4     glasses-square-green-blue-multi       nature

# %%
goop_df['catergory'].value_counts()
# Out:
# object         1832
# food           1681
# nature          971
# land_animal     945
# technology      682
# clothing        669
# sea_animal      577
# transport       415
# mythical        414
# human_part      377
# space           346
# building        335
# art             196
# sports          187
# bird            176
# drink           154
# Name: catergory, dtype: int64

# %%
# Out:
# 10000

# %%
# Out:
# Empty DataFrame
# Columns: [bgcolor, body, accessory, head, glasses, catergory]
# Index: []
